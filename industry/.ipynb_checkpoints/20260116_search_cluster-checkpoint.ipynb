# %%
import os
import glob
import s3fs

import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np


import datetime
import json
import re
import tqdm

# %% [markdown]
# # Chargement des fichiers

# %%
# Create filesystem object
S3_ENDPOINT_URL = "https://" + os.environ["AWS_S3_ENDPOINT"]
fs = s3fs.S3FileSystem(client_kwargs={'endpoint_url': S3_ENDPOINT_URL})

BUCKET_OUT = "aluneau"
FILE_KEY_S3 = "data_pest/"
FILE_PATH_S3 = BUCKET_OUT + "/" + FILE_KEY_S3

# %%
fs.ls(BUCKET_OUT + "/" + FILE_KEY_S3)
# Out:
# ['aluneau/data_pest/.keep',
#  'aluneau/data_pest/industry',
#  'aluneau/data_pest/queries',
#  'aluneau/data_pest/tweets',
#  'aluneau/data_pest/tweets_pesticides2010_2013.csv',
#  'aluneau/data_pest/tweets_pesticides_2014.csv',
#  'aluneau/data_pest/tweets_pesticides_2015.csv',
#  'aluneau/data_pest/tweets_pesticides_2016.csv',
#  'aluneau/data_pest/tweets_pesticides_2017.csv',
#  'aluneau/data_pest/tweets_pesticides_2018-16Sept.csv',
#  'aluneau/data_pest/tweets_pesticides_2018-5mai.csv',
#  'aluneau/data_pest/tweets_pesticides_2018.csv',
#  'aluneau/data_pest/tweets_pesticides_2019.csv',
#  'aluneau/data_pest/tweets_pesticides_2019_jan-3jan.csv',
#  'aluneau/data_pest/tweets_pesticides_2019_jan-6fev.csv',
#  'aluneau/data_pest/tweets_pesticides_2020.csv',
#  'aluneau/data_pest/tweets_pesticides_janv-fevrier.csv',
#  'aluneau/data_pest/tweets_pesticides_mars-10sept.csv',
#  'aluneau/data_pest/users']

# %%
i = -1
for file in fs.ls(BUCKET_OUT + "/" + FILE_KEY_S3):
    if ".csv" in file :
        dict_id = {}
        file_path = BUCKET_OUT + "/" + FILE_KEY_S3 + "/" + file
        print(file)
        i+=1
        with fs.open(file, mode="r", newline = '') as csv_in:
            reader = csv.DictReader(csv_in)
            headers = reader.fieldnames
            for x in headers:
                if "id" in x:
                    dict_id[x] = str
        with fs.open(file, mode = "rb") as file_in:
            df0 = pd.read_csv(file_in, sep =",", dtype = dict_id, usecols=['id','user_id', 'text', 'user_screen_name', 'to_userid',
       'to_tweetid','mentioned_names', 'mentioned_ids','local_time'])

        if i > 0 :
            df = pd.concat([df, df0])
        else:
            df = df0.copy()
# Out:
# aluneau/data_pest/tweets_pesticides2010_2013.csv
# aluneau/data_pest/tweets_pesticides_2014.csv
# aluneau/data_pest/tweets_pesticides_2015.csv
# aluneau/data_pest/tweets_pesticides_2016.csv
# aluneau/data_pest/tweets_pesticides_2017.csv
# aluneau/data_pest/tweets_pesticides_2018-16Sept.csv
# aluneau/data_pest/tweets_pesticides_2018-5mai.csv
# aluneau/data_pest/tweets_pesticides_2018.csv
# aluneau/data_pest/tweets_pesticides_2019.csv
# aluneau/data_pest/tweets_pesticides_2019_jan-3jan.csv
# aluneau/data_pest/tweets_pesticides_2019_jan-6fev.csv
# aluneau/data_pest/tweets_pesticides_2020.csv
# aluneau/data_pest/tweets_pesticides_janv-fevrier.csv
# aluneau/data_pest/tweets_pesticides_mars-10sept.csv

# %%
tweets= df.drop_duplicates()
tweets['local_time'] = pd.to_datetime(tweets['local_time'])
#tweets


print (len(tweets))
# Out:
# 1351278
# /tmp/ipykernel_1524/620171187.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets['local_time'] = pd.to_datetime(tweets['local_time'])

# %%
tweets.loc[tweets.user_id=="1125791906548592642"]
# Out:
# Empty DataFrame
# Columns: [id, local_time, user_screen_name, text, to_userid, to_tweetid, user_id, mentioned_names, mentioned_ids]
# Index: []

# %%
def upload_csvfile(file_path, cols_to_keep=None):
    dict_id = {}
    with fs.open(file_path, mode="r", newline = '') as csv_in:
        reader = csv.DictReader(csv_in)
        headers = reader.fieldnames
        for x in headers:
            if "id" in x:
                dict_id[x] = str
    with fs.open(file_path, mode = "rb") as file_in:
        data = pd.read_csv(file_in, sep =",", dtype = dict_id, usecols= cols_to_keep)

    return data

# %%
FILE_KEY_S3 = "data_pest/industry"
name_file = "20250902_pesticides_industries.csv"



file_path = BUCKET_OUT + "/" + FILE_KEY_S3 + "/" + name_file
print(file_path)

users0 = upload_csvfile(file_path, cols_to_keep=None)
users0


dict_col = {}
            
for x in ['field_work_x', 'metier_x', 'Ingenieur_x', 'Agronome_x',
       'industry_verif_x', 'field_work_y', 'metier_y', 'Ingenieur_y',
       'Agronome_y', 'industry_verif_y']:
    dict_col[x] = x.replace("_x","").replace('_y',"")

users0 = users0[['user_id', 'user_screen_name', 'user_description',
       'account_publication', 'industry', 'Type_entite', 'company', 'UIPP',
       'field_work_x', 'metier_x', 'Ingenieur_x', 'Agronome_x',
       'industry_verif_x']].rename(columns=dict_col)
# Out:
# aluneau/data_pest/industry/20250902_pesticides_industries.csv

# %%
FILE_KEY_S3 = "data_pest/users"
name_file = "the_true_all_annotated_account.csv"



file_path = BUCKET_OUT + "/" + FILE_KEY_S3 + "/" + name_file
print(file_path)

users1 = upload_csvfile(file_path, cols_to_keep=None)

users1["user_description"] = users1.user_description.str.replace("\n", " ")
users1["user_description"] = users1.user_description.str.replace(",", " ")
#users1.to_csv(f"{path_base}the_true_all_annotated_account.csv", sep = ",", index = False)
#users1 = users1.drop_duplicates().loc[users1["platform"]=="twitter"]
users1 = users1[['user_id', 'user_screen_name', 'user_name', 'Type_entite',
       'User_role', 'user_description', 'account_publication', 
       'Synthetic_logics']].drop_duplicates()#.reset_index()
# Out:
# aluneau/data_pest/users/the_true_all_annotated_account.csv

# %%
keep_all = True #Pour garder ou pas les comptes d'industries dont on a pas collecté les retweets

list_col = ['user_id', 'user_screen_name',
       'user_description', 'account_publication', 'Type_entite']

if keep_all == True:
    users1b = users1.merge(users0, on = list_col, how = "left")
    already_in_users1 = [x for x in users1b.user_id.unique()]
    users2 = users0.loc[~users0["user_id"].isin(already_in_users1)]
    #print(len(users), len(users0))
    
    users = pd.concat([users1b, users2], ignore_index=True)
else:
    users = users1.merge(users0, on = list_col, how = "left")
    


len(users)
# Out:
# 691

# %%
users1
# Out:
#                  user_id user_screen_name                    user_name  \
# 0               25661273         agriavis                     Agriavis
# 1             2385005515     Lucie_Pichon                 Lucie Pichon
# 2     710894045820801024     csfldefrance                         CSFL
# 3     846068351461982208  lafermeparthiot            La ferme Parthiot
# 4    1240716100280758272  noschampsfuturs  Notre futur dans les champs
# ..                   ...              ...                          ...
# 495  1110816447272574977     Grabotte2019                     Grabotte
# 496   767414190265004032      agronomix22               Lionel Mesnage
# 497             15595854        gbeuvelot                    gbeuvelot
# 498   916215358075359232  chasseurdedahut                     Romain L
# 499   930731261831909376      asmonaco972             AristoteSocrates
#
#       Type_entite                                          User_role  \
# 0    Organisation                                              Média
# 1        Personne                                              Média
# 2    Organisation  Groupement de producteurs et productrices agri...
# 3    Organisation                              Exploitation agricole
# 4    Organisation                                 mouvements sociaux
# ..            ...                                                ...
# 495      Personne                                       Commentateur
# 496      Personne                                       Chercheur.se
# 497      Personne                                       Commentateur
# 498      Personne                              Exploitation agricole
# 499      Personne                                                NaN
#
#                                       user_description  account_publication  \
# 0    L'avis des agriculteurs! Donnez votre avis sur...                  158
# 1    Community Manager à @Agriaffaires #agriculture...                  246
# 2    Des maraîchers et des arboriculteurs de terrai...                  270
# 3    Nous sommes agriculteurs dans le département d...                  237
# 4    Depuis 2014  les anti-glyphosate ont conçu une...                  198
# ..                                                 ...                  ...
# 495                                                NaN                  265
# 496                                                NaN                  173
# 497  @Cobratex #Tech4Climate #lessCO2 #greenTech #c...                  138
# 498                                                  .                  184
# 499                                                NaN                  196
#
#                 Synthetic_logics
# 0         Agricultural Practices
# 1         Agricultural Practices
# 2    Agroindustrial_perspectives
# 3    Agroindustrial_perspectives
# 4    Agroindustrial_perspectives
# ..                           ...
# 495     Rationalist_perspectives
# 496                          NaN
# 497                          NaN
# 498                          NaN
# 499                          NaN
#
# [500 rows x 8 columns]

# %%
users.loc[(users["industry_verif"].isna()), "industry"]=False
users.loc[(users["industry_verif"] == True), "industry"]=True
users.loc[(users["industry"].isna()) | (users["industry"]==False) , "company"]="irrelevent"
users.loc[(users["industry"]==True) & (users["company"].isna()) , "company"]= "Unknown"



users = users.drop_duplicates(["user_screen_name","user_id","industry", "Type_entite"])

dict_logic = dict(zip(users.user_id, users.Synthetic_logics))
users["Synthetic_logics2"] = users.user_id.map(dict_logic.get)
users.loc[(users.industry==True), "Synthetic_logics2"] = "industry_pesticide"

dict_translation = {'industry_pesticide':'Industries pesticides', 
              'Agricultural Practices':'Pratiques agricoles',
       'Agroindustrial_perspectives':'Perspectives agroindustrielles', 
              'Comment_the_news':'Commentaires de l\'actualité',
       'Ecological_perspectives':'Perspectives écologiques', 
              'Health_perspectives':'Perspectives sanitaires',
       'Marketing_logic':'Perspectives commerciales', 
              'Pesticide_free_agriculture':'Lutte contre les pesticides',
       'Rationalist_perspectives':'Perspectives rationalistes'}

users["Synthetic_logicsfr"]= users.Synthetic_logics2.map(dict_translation.get)

# %%
dict_logic2 = dict(zip(users.user_id, users.Synthetic_logics2))

#tweets["to_username"] = tweets.to_userid.map(dict(zip(users.user_id, users.user_screen_name)).get)

tweets["logic"] = tweets.user_id.map(dict_logic2.get)

tweets["company"] = tweets.user_id.map(dict(zip(users.user_id, users.company)).get)

tweets["industry"] = tweets.user_id.map(dict(zip(users.user_id, users.industry_verif)).get)
# Out:
# /tmp/ipykernel_1524/2373128351.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets["logic"] = tweets.user_id.map(dict_logic2.get)
# /tmp/ipykernel_1524/2373128351.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets["company"] = tweets.user_id.map(dict(zip(users.user_id, users.company)).get)
# /tmp/ipykernel_1524/2373128351.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets["industry"] = tweets.user_id.map(dict(zip(users.user_id, users.industry_verif)).get)

# %%
tweets
# Out:
#                         id          local_time user_screen_name  \
# 0       418160912399228928 2013-12-31 23:25:05        Magohamot
# 1       418139412447232000 2013-12-31 21:59:39    Centro_Smiles
# 2       418090542032257024 2013-12-31 18:45:27    Bouvier_Cyril
# 3       418068033488572417 2013-12-31 17:16:01     EndEcocideFR
# 4       418066709929410563 2013-12-31 17:10:45         serge8le
# ...                    ...                 ...              ...
# 69621  1366194559009579016 2021-03-01 01:12:20          fefegpe
# 69622  1366189548028395523 2021-03-01 00:52:25          Itya972
# 69623  1366182222533971970 2021-03-01 00:23:18   FR24NewsFrance
# 69624  1366179592533401603 2021-03-01 00:12:51         WanjuAGA
# 69625  1366176624794869760 2021-03-01 00:01:04        LYFtvNews
#
#                                                     text   to_userid  \
# 0      Ce champagne est vraiment pas super, il va fin...         NaN
# 1      Chlorinated hydrocarbon insecticide disengagem...         NaN
# 2      Les insecticides menacent la santé humaine  ht...         NaN
# 3      La fausse annonce du gouvernement français sur...         NaN
# 4      Monsanto, pesticides et OGM - L'Express avec L...         NaN
# ...                                                  ...         ...
# 69621  Élus de Martinique et de Guadeloupe: Contre un...         NaN
# 69622  Élus de Martinique et de Guadeloupe: Contre un...         NaN
# 69623  Des milliers de personnes manifestent en Marti...         NaN
# 69624  @tuCpakoa Et la couronne de cette belle pomme ...  4895013502
# 69625  Martinique : forte mobilisation contre la pres...         NaN
#
#                 to_tweetid              user_id mentioned_names mentioned_ids  \
# 0                      NaN            138143061             NaN           NaN
# 1                      NaN           1228468585             NaN           NaN
# 2                      NaN           2213873612             NaN           NaN
# 3                      NaN           2183781686             NaN           NaN
# 4                      NaN           1129266632      lexpansion      37981754
# ...                    ...                  ...             ...           ...
# 69621                  NaN            967980265          change      15947602
# 69622                  NaN             86725632    changefrance     603139314
# 69623                  NaN  1245483551749005312             NaN           NaN
# 69624  1364918981912637442           1954997959        tucpakoa    4895013502
# 69625                  NaN             14917992             NaN           NaN
#
#       logic company industry
# 0      None    None     None
# 1      None    None     None
# 2      None    None     None
# 3      None    None     None
# 4      None    None     None
# ...     ...     ...      ...
# 69621  None    None     None
# 69622  None    None     None
# 69623  None    None     None
# 69624  None    None     None
# 69625  None    None     None
#
# [1351278 rows x 12 columns]

# %%
from search_regex import queries_in_dictionnary, texts_in_dictionnaries, search_regex

# %%
dict_text = dict(zip(tweets.id, tweets.text.str.lower()))

FILE_KEY_S3 = "data_pest/queries"
name_file = "list_of_queries.csv"

file_path = BUCKET_OUT + "/" + FILE_KEY_S3 + "/" + name_file


queries = upload_csvfile(file_path)


dict_queries = queries_in_dictionnary(data = queries, 
                                      column_name_of_queries = "nom_cluster.3", 
                                      list_of_regex = ["query_1"])

dict_queries
# Out:
# {'Le vin': ['vigne|viticult|\\bvin(s*)\\b'],
#  'Plan écophyto': ['écophyto|zéro phyto(s*)'],
#  'Transition écologique et débats publics': ['débat(s*) public(s*)|convention(s*) citoyenne(s*)|transition.*écologique(s*)'],
#  'Épandages et riverains': ['épandage|pulvéris(ations*)'],
#  'Le rapport du CIRC': ['\\bcirc\\b|(centre|centre international) .*recherche.*cancer|\\biarc\\b'],
#  'SDHI': ['\\bsdhi\\b'],
#  'Affaire Triskalia': ['triskalia|nutréa|nutrea|(nutréa||nutrea)-triskalia'],
#  'Les espèces nuisibles': ['insecte|parasite|ravageur'],
#  'Le virus Zika': ['zika'],
#  'Chlordécone': ['chlordécone'],
#  'La mortalité des abeilles': ['abeille|apicult'],
#  'Néonicotinoïdes': ['(néo|neo)-?nic(otino(ï|i)de*)|(néo|neo)-?nic(s*)'],
#  'Procès de Monsanto': ['monsanto'],
#  'La science en question': ['science|scientifique'],
#  'Politiques agricoles françaises': ['Travert|sortie|loi alimentation|loi agriculture'],
#  'La crise de la biodiversité': ['biodiversité'],
#  'Perturbateurs endocriniens': ['endocrinien'],
#  "Pollution de l'eau": ['(pollution|contamination)(s*).*\\b(eau|phréatique(s*))\\b'],
#  'Sécurité des aliments': ['consomm|fipronil'],
#  'Réchauffement climatique': ['climatique'],
#  'Régulation européenne': ['commission européenne|autorité(s*) européenne(s*)|europe'],
#  'Troubles de santé': ['troubles.\\w*\\b.*\\w*\\b|thyroïd|alzheimer|parkinson|menstruel|cancer|cardiovasculaire'],
#  'Glyphosate': ['glypho*|glyphosate']}

# %%
d = search_regex(dict_queries = dict_queries, dict_text = dict_text)
d["somme"] = d.sum(axis=1)
# Out:
#   4%|▍         | 1/23 [00:19<07:09, 19.54s/it]
# Le vin : 26882
#   9%|▊         | 2/23 [00:30<05:06, 14.61s/it]
# Plan écophyto : 2577
#  13%|█▎        | 3/23 [00:45<04:57, 14.86s/it]
# Transition écologique et débats publics : 2803
#  17%|█▋        | 4/23 [00:57<04:17, 13.54s/it]
# Épandages et riverains : 20551
#  22%|██▏       | 5/23 [01:21<05:12, 17.36s/it]
# Le rapport du CIRC : 4663
#  26%|██▌       | 6/23 [01:32<04:19, 15.29s/it]
# SDHI : 5836
#  30%|███       | 7/23 [02:01<05:15, 19.71s/it]
# Affaire Triskalia : 1242
#  35%|███▍      | 8/23 [02:18<04:40, 18.71s/it]
# Les espèces nuisibles : 18861
#  39%|███▉      | 9/23 [02:24<03:26, 14.76s/it]
# Le virus Zika : 2337
#  43%|████▎     | 10/23 [02:30<02:36, 12.02s/it]
# Chlordécone : 28102
#  48%|████▊     | 11/23 [02:36<02:04, 10.34s/it]
# La mortalité des abeilles : 117164
#  52%|█████▏    | 12/23 [02:50<02:06, 11.46s/it]
# Néonicotinoïdes : 98069
#  57%|█████▋    | 13/23 [02:56<01:37,  9.76s/it]
# Procès de Monsanto : 85662
#  61%|██████    | 14/23 [03:05<01:25,  9.50s/it]
# La science en question : 65251
#  65%|██████▌   | 15/23 [03:23<01:36, 12.04s/it]
# Politiques agricoles françaises : 17581
#  70%|██████▉   | 16/23 [03:29<01:11, 10.16s/it]
# La crise de la biodiversité : 19584
#  74%|███████▍  | 17/23 [03:35<00:54,  9.01s/it]
# Perturbateurs endocriniens : 10004
#  78%|███████▊  | 18/23 [03:48<00:50, 10.12s/it]
# Pollution de l'eau : 2149
#  83%|████████▎ | 19/23 [03:58<00:41, 10.31s/it]
# Sécurité des aliments : 24271
#  87%|████████▋ | 20/23 [04:04<00:26,  8.92s/it]
# Réchauffement climatique : 6273
#  91%|█████████▏| 21/23 [04:18<00:21, 10.53s/it]
# Régulation européenne : 60965
#  96%|█████████▌| 22/23 [04:43<00:14, 14.73s/it]
# Troubles de santé : 48369
# 100%|██████████| 23/23 [04:48<00:00, 12.55s/it]
# Glyphosate : 402959

# %%
d["id"] = d.index
list_column = list(d.columns)[0:-2]
list_column
# Out:
# ['Le vin',
#  'Plan écophyto',
#  'Transition écologique et débats publics',
#  'Épandages et riverains',
#  'Le rapport du CIRC',
#  'SDHI',
#  'Affaire Triskalia',
#  'Les espèces nuisibles',
#  'Le virus Zika',
#  'Chlordécone',
#  'La mortalité des abeilles',
#  'Néonicotinoïdes',
#  'Procès de Monsanto',
#  'La science en question',
#  'Politiques agricoles françaises',
#  'La crise de la biodiversité',
#  'Perturbateurs endocriniens',
#  "Pollution de l'eau",
#  'Sécurité des aliments',
#  'Réchauffement climatique',
#  'Régulation européenne',
#  'Troubles de santé',
#  'Glyphosate']

# %%
tweets.columns
# Out:
# Index(['id', 'local_time', 'user_screen_name', 'text', 'to_userid',
#        'to_tweetid', 'user_id', 'mentioned_names', 'mentioned_ids', 'logic',
#        'company', 'industry'],
#       dtype='object')

# %%
d["logic"] = d.id.map(dict(zip(tweets.id, tweets.logic)).get)
d["user_id"] = d.id.map(dict(zip(tweets.id, tweets.user_id)).get)
d["user_screen_name"] = d.id.map(dict(zip(tweets.id, tweets.user_screen_name)).get)
d["industry"] = d.id.map(dict(zip(tweets.id, tweets.industry)).get)
d_industry = d.loc[d.industry==True]

# %%
d1 = d.loc[(d.somme>0) & ~(d.logic.isna())]
d1_industry = d1.loc[d1.industry==True]
d1_industry
# Out:
#                      Le vin  Plan écophyto  \
# 411419022584852480        0              0
# 410075807894503424        0              0
# 409978788735250433        0              0
# 408966816531501056        0              0
# 403091623464026112        0              0
# ...                     ...            ...
# 1366860672542334983       0              0
# 1366680739341869060       0              0
# 1366437716058116103       0              0
# 1366436552033918979       0              0
# 1366430170425524226       1              0
#
#                      Transition écologique et débats publics  \
# 411419022584852480                                         0
# 410075807894503424                                         0
# 409978788735250433                                         0
# 1366436552033918979  819961168831901696       LeluOlivier      True
# 1366430170425524226  819961168831901696       LeluOlivier      True
#
# [2479 rows x 29 columns]

# %%
f_sdhi = d.groupby(["logic"]).agg(nb = ("SDHI", "sum")).reset_index()
f_sdhi["freq"] = f_sdhi.nb / np.sum(f_sdhi.nb)*100
f_sdhi.sort_values("freq", ascending=False)
# Out:
#                          logic   nb       freq
# 1  Agroindustrial_perspectives  777  32.213930
# 3      Ecological_perspectives  677  28.067993
# 8           industry_pesticide  311  12.893864
# 6   Pesticide_free_agriculture  213   8.830846
# 2             Comment_the_news  189   7.835821
# 7     Rationalist_perspectives  169   7.006633
# 4          Health_perspectives   63   2.611940
# 5              Marketing_logic    8   0.331675
# 0       Agricultural Practices    5   0.207297

# %%
d.loc[(d.SDHI == 1)&(d.logic=="Ecological_perspectives")].groupby(["user_screen_name"]).agg(nb=("user_id","size")).reset_index().sort_values("nb")
# Out:
#    user_screen_name   nb
# 0   20minutesplanet    1
# 3      AndreMINETTO    1
# 7           BSolist    1
# 4    ArnaudApoteker    1
# 12      CapEcologie    1
# ..              ...  ...
# 11   CabinetGimalac   33
# 5      AssoPollinis   43
# 81        mjthcap21   44
# 38         PHurlaux   46
# 26  GaiaGreenRiding  175
#
# [88 rows x 2 columns]

# %%
d2 = d.loc[d.logic.isin(['Health_perspectives', 'Pesticide_free_agriculture',
       'Ecological_perspectives', 'Agroindustrial_perspectives','Comment_the_news',
       'Rationalist_perspectives',
       'industry_pesticide']) & (d.somme>0)]
d2.logic.unique()
# Out:
# array(['Comment_the_news', 'Ecological_perspectives',
#        'Pesticide_free_agriculture', 'Health_perspectives',
#        'Agroindustrial_perspectives', 'industry_pesticide',
#        'Rationalist_perspectives'], dtype=object)

# %%
import numpy as np

# %%
i=-1
for n, x in enumerate(d2.logic.unique()):
    i+=1
    list_size = []
    list_name_cluster= []
    for c in list_column:
        list_size.append(np.sum(d2[c].loc[d2.logic == x]))
        list_name_cluster.append(c)
    data = {"cluster": list_name_cluster, "nb":list_size}
    df0 = pd.DataFrame(data)
    df0["logic"] = x
    if i == 0:
        df = df0.copy()
    else:
        df = pd.concat([df,df0])
    


i = -1
df1 = tweets.loc[tweets.logic.isin(['Health_perspectives', 'Pesticide_free_agriculture',
       'Ecological_perspectives', 'Agroindustrial_perspectives','Comment_the_news',
       'Rationalist_perspectives',
       'industry_pesticide'])].groupby(["logic"])["logic"].count().reset_index(name='count')
df1
# Out:
#                          logic  count
# 0  Agroindustrial_perspectives  54452
# 1             Comment_the_news  29616
# 2      Ecological_perspectives  63349
# 3          Health_perspectives  11479
# 4   Pesticide_free_agriculture  21636
# 5     Rationalist_perspectives  16232
# 6           industry_pesticide   4654

# %%
df
# Out:
#                                     cluster    nb                     logic
# 0                                    Le vin   644          Comment_the_news
# 1                             Plan écophyto    35          Comment_the_news
# 2   Transition écologique et débats publics    99          Comment_the_news
# 3                    Épandages et riverains   344          Comment_the_news
# 4                        Le rapport du CIRC   230          Comment_the_news
# ..                                      ...   ...                       ...
# 18                    Sécurité des aliments   437  Rationalist_perspectives
# 19                 Réchauffement climatique   132  Rationalist_perspectives
# 20                    Régulation européenne   484  Rationalist_perspectives
# 21                        Troubles de santé   914  Rationalist_perspectives
# 22                               Glyphosate  8167  Rationalist_perspectives
#
# [161 rows x 3 columns]

# %%
df.loc[df.cluster.str.contains("Chlordécone")]
# Out:
#        cluster    nb                        logic
# 9  Chlordécone  1161             Comment_the_news
# 9  Chlordécone   998      Ecological_perspectives
# 9  Chlordécone   224   Pesticide_free_agriculture
# 9  Chlordécone   133          Health_perspectives
# 9  Chlordécone    68  Agroindustrial_perspectives
# 9  Chlordécone     0           industry_pesticide
# 9  Chlordécone    39     Rationalist_perspectives

# %%
freq_1 = df['nb'].loc[df.cluster=="Le vin"].values
freq_g1 = df1['count'].values
sum(freq_1)
# Out:
# np.int64(4041)

# %%
freq_g=freq_g1/sum(freq_g1)*sum(freq_1)
freq_g
# Out:
# array([1092.45713889,  594.17855405, 1270.95547071,  230.30036541,
#         434.07776862,  325.65864024,   93.37206208])

# %%
np.log(0)
# Out:
# /tmp/ipykernel_1524/2933082444.py:1: RuntimeWarning: divide by zero encountered in log
#   np.log(0)
# np.float64(-inf)

# %%
from scipy.stats import kstest

from numpy.random import seed
from numpy.random import poisson
from numpy.random import randn
from numpy.random import lognormal

from scipy.stats import chisquare

# %%
statistics_topic={}
for topic in df["cluster"].unique():
    freq1  = df.loc[df["cluster"]==topic]
    freq_1=freq1['nb'].values
    if len(freq_1)==len(freq_g):
        ch=chisquare(f_obs=freq_1/sum(freq_1)*sum(freq_g), f_exp=freq_g)
        if ch.pvalue < .5:
            statistics_topic[topic]=ch.statistic
#            print(topic,ch)

# %%
statistics_topic
# Out:
# {'Le vin': np.float64(1690.302982213259),
#  'Plan écophyto': np.float64(5036.9819069786545),
#  'Transition écologique et débats publics': np.float64(2839.4734351070388),
#  'Épandages et riverains': np.float64(4254.696939161286),
#  'Le rapport du CIRC': np.float64(10673.08565723751),
#  'SDHI': np.float64(4047.544235214716),
#  'Affaire Triskalia': np.float64(8660.772726976038),
#  'Les espèces nuisibles': np.float64(4768.32401962297),
#  'Le virus Zika': np.float64(3389.286320465444),
#  'Chlordécone': np.float64(3205.9750975480747),
#  'La mortalité des abeilles': np.float64(3196.67426737693),
#  'Néonicotinoïdes': np.float64(3866.103157987006),
#  'Procès de Monsanto': np.float64(1981.612387941176),
#  'La science en question': np.float64(5659.74637201699),
#  'Politiques agricoles françaises': np.float64(4212.182439547897),
#  'La crise de la biodiversité': np.float64(5248.886747518904),
#  'Perturbateurs endocriniens': np.float64(3509.7759087510913),
#  "Pollution de l'eau": np.float64(3433.234962911717),
#  'Sécurité des aliments': np.float64(4747.1035615782885),
#  'Réchauffement climatique': np.float64(6236.597243279402),
#  'Régulation européenne': np.float64(3496.2625387603034),
#  'Troubles de santé': np.float64(3788.4760178037022),
#  'Glyphosate': np.float64(5401.976831749481)}

# %%
a1_sorted_keys = sorted(statistics_topic, key=statistics_topic.get, reverse=True)
for r in a1_sorted_keys:
    print(r, statistics_topic[r])
# Out:
# Le rapport du CIRC 10673.08565723751
# Affaire Triskalia 8660.772726976038
# Réchauffement climatique 6236.597243279402
# La science en question 5659.74637201699
# Glyphosate 5401.976831749481
# La crise de la biodiversité 5248.886747518904
# Plan écophyto 5036.9819069786545
# Les espèces nuisibles 4768.32401962297
# Sécurité des aliments 4747.1035615782885
# Épandages et riverains 4254.696939161286
# Politiques agricoles françaises 4212.182439547897
# SDHI 4047.544235214716
# Néonicotinoïdes 3866.103157987006
# Troubles de santé 3788.4760178037022
# Perturbateurs endocriniens 3509.7759087510913
# Régulation européenne 3496.2625387603034
# Pollution de l'eau 3433.234962911717
# Le virus Zika 3389.286320465444
# Chlordécone 3205.9750975480747
# La mortalité des abeilles 3196.67426737693
# Transition écologique et débats publics 2839.4734351070388
# Procès de Monsanto 1981.612387941176
# Le vin 1690.302982213259

# %%
df1_n=df1.copy()
df1_n['count'] = (df1['count']+1) / (sum(df1['count'])+1)
df1_n
# Out:
#                          logic     count
# 0  Agroindustrial_perspectives  0.270347
# 1             Comment_the_news  0.147042
# 2      Ecological_perspectives  0.314518
# 3          Health_perspectives  0.056996
# 4   Pesticide_free_agriculture  0.107423
# 5     Rationalist_perspectives  0.080593
# 6           industry_pesticide  0.023111

# %%
for r in a1_sorted_keys:
    print(r)
# Out:
# Le rapport du CIRC
# Affaire Triskalia
# Réchauffement climatique
# La science en question
# Glyphosate
# La crise de la biodiversité
# Plan écophyto
# Les espèces nuisibles
# Sécurité des aliments
# Épandages et riverains
# Politiques agricoles françaises
# SDHI
# Néonicotinoïdes
# Troubles de santé
# Perturbateurs endocriniens
# Régulation européenne
# Pollution de l'eau
# Le virus Zika
# Chlordécone
# La mortalité des abeilles
# Transition écologique et débats publics
# Procès de Monsanto
# Le vin

# %%
freq_all=pd.DataFrame()
for r in a1_sorted_keys:
    freq1_n=df.loc[df.cluster==r].copy()
    freq1_n['count'] = (freq1_n['nb']+1) / (sum(freq1_n['nb'])+1)
    freq_duo=df1_n.merge(freq1_n,on='logic').rename(columns={'count_x':'global','count_y':'local'}).set_index('logic')
    freq_duo['zscore']=np.log((freq_duo['local'])/(freq_duo['global']))
    #del (freq_duo['local'])
    #del (freq_duo['global'])
    #del (freq_duo['nb'])
    print(freq_duo.columns)
    freq_all=pd.concat([freq_all,freq_duo],axis=0)
    freq_duo=df1_n.merge(freq1_n,on='logic').rename(columns={'count_x':'global','count_y':r}).set_index('logic')
    #freq_duo.plot(kind='bar')
    #plt.title("statistics= "+str(int(statistics_topic[r])))
    #plt.tight_layout()
    #plt.savefig('../image/freq_dist/'+r+'_'+category+'.png')
# Out:
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')
# Index(['global', 'cluster', 'nb', 'local', 'zscore'], dtype='object')

# %%
list_excluded = [x for x in freq_all.cluster.loc[freq_all.zscore==-np.inf]]
list_excluded
# Out:
# []

# %%
freq_all_cleaned = freq_all.replace(-np.inf, -10).reset_index()
freq_all_cleaned
# Out:
#                            logic    global             cluster    nb  \
# 0    Agroindustrial_perspectives  0.270347  Le rapport du CIRC   816
# 1               Comment_the_news  0.147042  Le rapport du CIRC   230
# 2        Ecological_perspectives  0.314518  Le rapport du CIRC   337
# 3            Health_perspectives  0.056996  Le rapport du CIRC    71
# 4     Pesticide_free_agriculture  0.107423  Le rapport du CIRC   106
# ..                           ...       ...                 ...   ...
# 156      Ecological_perspectives  0.314518              Le vin  1285
# 157          Health_perspectives  0.056996              Le vin   408
# 158   Pesticide_free_agriculture  0.107423              Le vin   751
# 159     Rationalist_perspectives  0.080593              Le vin   218
# 160           industry_pesticide  0.023111              Le vin   129
#
#         local    zscore
# 0    0.396795  0.383713
# 1    0.112190 -0.270519
# 2    0.164157 -0.650217
# 3    0.034968 -0.488529
# 4    0.051967 -0.726164
# ..        ...       ...
# 156  0.318159  0.011509
# 157  0.101188  0.574001
# 158  0.186047  0.549224
# 159  0.054181 -0.397082
# 160  0.032162  0.330485
#
# [161 rows x 6 columns]

# %%
ct=pd.crosstab(freq_all_cleaned["cluster"], freq_all_cleaned.logic,values=freq_all_cleaned['zscore'],aggfunc="sum")
ct
# Out:
# logic                                    Agroindustrial_perspectives  \
# cluster
# Affaire Triskalia                                          -3.933698
# Chlordécone                                                -2.330299
# Glyphosate                                                  0.333601
# La crise de la biodiversité                                -0.235543
# La mortalité des abeilles                                  -0.464310
# La science en question                                      0.288774
# Le rapport du CIRC                                          0.383713
# Le vin                                                     -0.587917
# Le virus Zika                                              -0.283844
# Les espèces nuisibles                                       0.115138
# Néonicotinoïdes                                            -0.396699
# Perturbateurs endocriniens                                 -0.692544
# Plan écophyto                                              -0.134702
# Politiques agricoles françaises                             0.292202
# Pollution de l'eau                                         -0.815286
# Procès de Monsanto                                         -0.427866
# Réchauffement climatique                                    0.428025
# Régulation européenne                                      -0.053008
# SDHI                                                        0.181552
# Sécurité des aliments                                       0.280558
# Transition écologique et débats publics                    -0.075861
# Troubles de santé                                          -0.361979
# Épandages et riverains                                     -0.203088
#
# logic                                    Comment_the_news  \
# cluster
# Affaire Triskalia                               -0.328976
# Chlordécone                                      1.102482
# Glyphosate                                       0.055480
# La crise de la biodiversité                     -0.252072
# La mortalité des abeilles                       -0.239096
# La science en question                          -0.194200
# Le rapport du CIRC                              -0.270519
# Le vin                                           0.081794
# Le virus Zika                                   -0.245400
# Les espèces nuisibles                           -0.237353
# Néonicotinoïdes                                 -0.211067
# Perturbateurs endocriniens                      -0.095926
# Plan écophyto                                   -0.537313
# Politiques agricoles françaises                  0.108185
# Pollution de l'eau                               0.100433
# Procès de Monsanto                               0.179357
# Réchauffement climatique                         0.203322
# Régulation européenne                           -0.098843
# SDHI                                            -0.619161
# Sécurité des aliments                           -0.130122
# Transition écologique et débats publics          0.484338
# Troubles de santé                               -0.064411
# Épandages et riverains                          -0.216699
#
# logic                                    Ecological_perspectives  \
# cluster
# Affaire Triskalia                                       0.702457
# Chlordécone                                             0.191012
# Glyphosate                                             -0.419263
# La crise de la biodiversité                             0.402164
# La mortalité des abeilles                               0.208854
# La science en question                                 -0.283656
# Le rapport du CIRC                                     -0.650217
# Le vin                                                  0.011509
# Le virus Zika                                           0.166994
# Les espèces nuisibles                                   0.035136
# Néonicotinoïdes                                         0.325485
# Perturbateurs endocriniens                              0.245122
# Plan écophyto                                           0.422146
# Politiques agricoles françaises                        -0.120223
# Pollution de l'eau                                      0.373761
# Procès de Monsanto                                      0.017369
# Réchauffement climatique                               -0.379952
# Régulation européenne                                   0.171499
# SDHI                                                   -0.107364
# Sécurité des aliments                                  -0.157668
# Transition écologique et débats publics                 0.074669
# Troubles de santé                                      -0.072321
# Épandages et riverains                                  0.363301
#
# logic                                    Health_perspectives  \
# cluster
# Affaire Triskalia                                   0.918871
# Chlordécone                                        -0.109834
# Glyphosate                                         -0.545800
# La crise de la biodiversité                        -0.571278
# La mortalité des abeilles                           0.819103
# La science en question                             -0.502450
# Le rapport du CIRC                                 -0.488529
# Le vin                                              0.574001
# Le virus Zika                                       1.081832
# Les espèces nuisibles                              -0.908527
# Néonicotinoïdes                                     0.397027
# Perturbateurs endocriniens                          0.787554
# Plan écophyto                                      -0.037596
# Politiques agricoles françaises                    -0.446584
# Pollution de l'eau                                  0.445179
# Procès de Monsanto                                 -0.069242
# Réchauffement climatique                           -1.543563
# Régulation européenne                               0.107048
# SDHI                                               -0.759560
# Sécurité des aliments                              -0.495509
# Transition écologique et débats publics            -1.093648
# Troubles de santé                                   0.653660
# Épandages et riverains                              0.170703
#
# logic                                    Pesticide_free_agriculture  \
# cluster
# Affaire Triskalia                                          0.124730
# Chlordécone                                               -0.225372
# Glyphosate                                                -0.147682
# La crise de la biodiversité                               -0.344600
# La mortalité des abeilles                                  0.269042
# La science en question                                    -0.168476
# Le rapport du CIRC                                        -0.726164
# Le vin                                                     0.549224
# Le virus Zika                                              0.142652
# Les espèces nuisibles                                     -0.051564
# Néonicotinoïdes                                            0.051375
# Perturbateurs endocriniens                                 0.126848
# Plan écophyto                                             -0.093316
# Politiques agricoles françaises                           -0.155677
# Pollution de l'eau                                         0.335905
# Procès de Monsanto                                         0.596774
# Réchauffement climatique                                  -0.594952
# Régulation européenne                                     -0.087384
# SDHI                                                      -0.186265
# Sécurité des aliments                                     -0.202035
# Transition écologique et débats publics                   -0.223369
# Troubles de santé                                          0.193963
# Épandages et riverains                                    -0.076419
#
# logic                                    Rationalist_perspectives  \
# cluster
# Affaire Triskalia                                       -2.723406
# Chlordécone                                             -1.665235
# Glyphosate                                               0.362116
# La crise de la biodiversité                              0.009937
# La mortalité des abeilles                               -0.543852
# La science en question                                   0.453305
# Le rapport du CIRC                                       0.959103
# Le vin                                                  -0.397082
# Le virus Zika                                           -1.110434
# Les espèces nuisibles                                    0.295630
# Néonicotinoïdes                                         -0.348866
# Perturbateurs endocriniens                              -0.127390
# Plan écophyto                                           -0.629158
# Politiques agricoles françaises                         -0.328316
# Pollution de l'eau                                      -1.322646
# Procès de Monsanto                                      -0.122169
# Réchauffement climatique                                 0.292296
# Régulation européenne                                   -0.366978
# SDHI                                                    -0.129084
# Sécurité des aliments                                    0.146520
# Transition écologique et débats publics                 -0.428487
# Troubles de santé                                        0.449060
# Épandages et riverains                                  -0.884230
#
# logic                                    industry_pesticide
# cluster
# Affaire Triskalia                                 -0.375689
# Chlordécone                                       -4.105010
# Glyphosate                                        -0.196334
# La crise de la biodiversité                       -0.532718
# La mortalité des abeilles                         -0.786585
# La science en question                             0.245435
# Le rapport du CIRC                                 0.342162
# Le vin                                             0.330485
# Le virus Zika                                      0.649495
# Les espèces nuisibles                              0.005972
# Néonicotinoïdes                                   -0.904047
# Perturbateurs endocriniens                        -0.472220
# Plan écophyto                                     -0.324515
# Politiques agricoles françaises                   -0.810867
# Pollution de l'eau                                -0.227693
# Procès de Monsanto                                -0.964202
# Réchauffement climatique                          -0.404510
# Régulation européenne                             -0.142967
# SDHI                                               1.727225
# Sécurité des aliments                              0.255047
# Transition écologique et débats publics            0.214481
# Troubles de santé                                 -0.375827
# Épandages et riverains                            -0.808639

# %%
ct1=pd.crosstab(freq_all_cleaned["cluster"], freq_all_cleaned.logic,values=freq_all_cleaned['nb'],aggfunc="sum")
ct1
# Out:
# logic                                    Agroindustrial_perspectives  \
# cluster
# Affaire Triskalia                                                  0
# Chlordécone                                                       68
# Glyphosate                                                     26628
# La crise de la biodiversité                                      928
# La mortalité des abeilles                                       2211
# La science en question                                          5545
# Le rapport du CIRC                                               816
# Le vin                                                           606
# Le virus Zika                                                     22
# Les espèces nuisibles                                           1108
# Néonicotinoïdes                                                 2311
# Perturbateurs endocriniens                                       243
# Plan écophyto                                                     98
# Politiques agricoles françaises                                 1409
# Pollution de l'eau                                                38
# Procès de Monsanto                                              1699
# Réchauffement climatique                                         510
# Régulation européenne                                           2226
# SDHI                                                             777
# Sécurité des aliments                                           1679
# Transition écologique et débats publics                          104
# Troubles de santé                                               1363
# Épandages et riverains                                           642
#
# logic                                    Comment_the_news  \
# cluster
# Affaire Triskalia                                      19
# Chlordécone                                          1161
# Glyphosate                                          10966
# La crise de la biodiversité                           496
# La mortalité des abeilles                            1506
# La science en question                               1860
# Le rapport du CIRC                                    230
# Le vin                                                644
# Le virus Zika                                          12
# Les espèces nuisibles                                 423
# Néonicotinoïdes                                      1513
# Perturbateurs endocriniens                            240
# Plan écophyto                                          35
# Politiques agricoles françaises                       637
# Pollution de l'eau                                     52
# Procès de Monsanto                                   1696
# Réchauffement climatique                              221
# Régulation européenne                                1156
# SDHI                                                  189
# Sécurité des aliments                                 605
# Transition écologique et débats publics                99
# Troubles de santé                                     998
# Épandages et riverains                                344
#
# logic                                    Ecological_perspectives  \
# cluster
# Affaire Triskalia                                            119
# Chlordécone                                                  998
# Glyphosate                                                 14591
# La crise de la biodiversité                                 2044
# La mortalité des abeilles                                   5044
# La science en question                                      3639
# Le rapport du CIRC                                           337
# Le vin                                                      1285
# Le virus Zika                                                 41
# Les espèces nuisibles                                       1190
# Néonicotinoïdes                                             5537
# Perturbateurs endocriniens                                   724
# Sécurité des aliments                                   139
# Transition écologique et débats publics                  11
# Troubles de santé                                       114
# Épandages et riverains                                   29

# %%
import seaborn as sns
from matplotlib.colors import TwoSlopeNorm
rdgn = sns.diverging_palette(h_neg=130, h_pos=10, s=99, l=55, sep=3, as_cmap=True)
divnorm = TwoSlopeNorm(vmin=-1, vcenter=0, vmax=1)

fig=sns.clustermap(ct,method="centroid",cmap=rdgn, norm=divnorm,figsize=(10,20), 
                   dendrogram_ratio=(0.15,0.1), cbar_pos= (0.9, 0.8, 0.05, 0.18), mask = ct <= -10.0)

fig

# %%
fig.savefig("figures/clustermap_topic.jpg")

# %%
list_id = [x for x in d1.id.loc[d1["Sécurité des aliments"]==1]]

# %%
df_tmp = tweets.loc[(tweets.logic=="industry_pesticide") & (tweets.id.isin(list_id))]
for n, x in enumerate(df_tmp.text):
    print('########\n', x, f"[{df_tmp.user_screen_name.iloc[n]}]")
# Out:
# ########
#  Baisse de la consommation des #pesticides en France. http://ideesliquidesetsolides.blogspot.com/2013/12/baisse-de-la-consommation-des.html [UIPPorg]
# ########
#  @omalbanate Rapportée à la consommation moyenne de pesticides par hectare cultivé,  la France se place dans une position moyenne. [UIPPorg]
# ########
#  Une invention danoise permettrait de réduire significativement la consommation de pesticides A suivre! http://ln.is/diplomatie.gouv.fr/QifYS [qualidon]
# ########
#  #Abeilles et pesticides : l’Efsa va réévaluer le fipronil via @FranceAgricole http://buff.ly/1O5KgTE [DESANGOSSE]
# ########
#  #EnvoyeSpecial les résidus de pesticides n'impliquent pas de risque pour le consommateur dès lors que leurs niveaux respectent les LMR [UIPPorg]
# ########
#  "Le maïs est la plante qui consomme le moins de pesticides", c'est l'info de Semence Mag du jour #CAMPAGNESTV https://twitter.com/BBoniere/status/569092296437850112/photo/1 [BBoniere]
# ########
#  Rapport « Résidus de #pesticides dans les aliments » : le risque pour les consommateurs reste faible via @EFSA_EU http://bit.ly/2eZ19DR [Bayer_FR]
# ########
#  FAUX: La France est le plus gros consommateur de pesticides en Europe / BALIVERNE #11  http://agriculture-environnement.fr/treve-de-balivernes/france-plus-gros-consommateur-de-pesticides-europe-baliverne-11#.V9Z9y3uOc7A.twitter [petatJM]
# ########
#  @ABriac où avez vous vu que l Inra accusait " les pesticides"? L étude ne concerne que fipronil retiré du marché..depuis 10ans. quel scoop!! [petatJM]
# ########
#  La France est le plus gros consommateur de pesticides en Europe / BALIVE... http://ln.is/www.youtube.com/PszDV via @YouTube [qualidon]
# ########
#  Les agriculteurs français surconsommateurs de #pesticides ? via @afis_science http://urlz.fr/2VnY [UIPPorg]
# ########
#  .@ChLambert_FNSEA chez @JJBourdin_RMC «Avec le #CETA, le gouvernement va faire venir des produits du Canada contenant 43 molécules antibiotiques, pesticides, hormones interdites en France. Nos agriculteurs ont le sentiment d’être trompés et les consommateurs floués» #lesieclevert [sieclevert]
# ########
#  @GARREAU75 quel rapport? La consommation moyenne de pesticides/ ha en France est la 6eme en Europe et - 50%  tonnages #pesticides en 15 ans [petatJM]
# ########
#  Voila voila pour la surconsommation de pesticides... « AcademieAgri: Comment se situe la consommation de #pesticides en France, comparée au reste de l'#Europe ? Un nouveau "#Repères" de notre encyclopédie en ligne apporte une réponse #factchecking ! A lire ici : https://www.academie-agriculture.fr/publications/encyclopedie/reperes/quantite-moyenne-des-substances-phytopharmaceutiques-utilisees-en https://twitter.com/AcademieAgri/status/1069875460111302656/photo/1 — https://twitter.com/AcademieAgri/status/1069875460111302656 » [Pat2816]
# ########
#  Mauvaise opinion répandue : "L’agriculture française est une grosse consommatrice de pesticides." FAUX  LA FRANCE EST PROCHE DE LA MOYENNE EUROPEENNE ! 👍https://www.academie-agriculture.fr/publications/encyclopedie/reperes/quantite-moyenne-des-substances-phytopharmaceutiques-utilisees-en @FMCAgro #communicationpositive [BenichonMaxime]
# ########
#  Interessant de remettre les choses en place pour les #pesticides et l' #agriculture Française. @genefutures il n'y a pas que les tonnages qui comptent ! @coquelicots_  vous pouvez peut être aller vous installer à Malte ? « AcademieAgri: Comment se situe la consommation de #pesticides en France, comparée au reste de l'#Europe ? Un nouveau "#Repères" de notre encyclopédie en ligne apporte une réponse #factchecking ! A lire ici : https://www.academie-agriculture.fr/publications/encyclopedie/reperes/quantite-moyenne-des-substances-phytopharmaceutiques-utilisees-en https://twitter.com/AcademieAgri/status/1069875460111302656/photo/1 — https://twitter.com/AcademieAgri/status/1069875460111302656 » [fastier_antony]
# ########
#  Bravo Jean Marc de montrer au grand public que les protections des  cultures par des fongicides est importante pour la qualité des produits que nous consommons. #fusariose  #BASF « BASF_FR: Quelle conséquence d’un #blé attaqué par la #fusariose sur la qualité de notre #alimentation ?
# ➡ Explications avec @petatJM https://twitter.com/BASF_FR/status/1065991018053541888/video/1 — https://twitter.com/BASF_FR/status/1065991018053541888 » [GrubertP]
# ########
#  Pesticides les plus consommés en @Occitanie : le soufre, base de la protection en agriculture biologique truste le podium!! Merci @générations futures pour votre franchise
# https://bit.ly/2DMvINv [MartyRgis1]
# ########
#  @geninbv @francoislegendr En complément d'info, cette étude souligne que sans glyphosate, la consommation de carburant augmenterait & pourrait engendrer des émissions de dioxyde de carbone équivalentes à celles de 1,15 million de voitures. En espérant que cela vous soit utile. https://doi.org/10.1080/21645698.2017.1390637 2/2 [Bayer_FR]
# ########
#  #ColloqueDEPHY la #banane est aussi à l honneur ! De gros écarts de consommation phytosanitaire entre la #Martinique et d autres pays tropicaux (7 fois moins de #phyto 🇫🇷🤠 https://twitter.com/qualidon/status/1062298696925224960/photo/1 [qualidon]
# ########
#  #pesticides Au Royaume-Uni pas de baisse de la  consommation de #phytos par la séparation du conseil et la vente selon Jéremy Macklins  🤠🧐@NegoceAgricole @CoopdeFrance  @UIPPorg http://uipp.org/Actualites/Au-Royaume-Uni-separer-le-conseil-et-la-vente-n-a-pas-reduit-le-volume-des-produits-phytosanitaires-utilises https://twitter.com/qualidon/status/1060793319666696193/photo/1 [qualidon]
#  si je n'ai pas mis @BASFAgro dans mon profil twiiter c'est que je m'exprime en mon nom. Et en tant que toxicologue dans une boite phyto, cela n’empêche pas d'avoir une éthique personnelle et un esprit critique. « mostapapa: @fastier_antony @podeus69 @LilyDear @ORiNOCO_117 Cela  dit ce n’est pas le rôle de BASF de s’occuper de la santé des opérateurs, consommateurs et l’environnement, sans intérêt c’est de vendre des produits. — https://twitter.com/mostapapa/status/1203663770062655488 » [fastier_antony]
# ########
#  @HalleBruno1 @MichelMagniez @EELVpicardie @a_saint_quentin @WEO_TV "Dire que demain on arrête les #phyto est complètement utopique. Il faut profiter de toutes les innovations pour protéger au mieux les consommateurs, les terres et le vivant" @michelmagniez https://twitter.com/sieclevert/status/1202606731479732224/photo/1 [sieclevert]
# ########
#  @melanie_rsn @PicocheD @AEGRW @LADN_EU Rappel
# Agriculture actuelle : la plus durable au monde et qui
# En + diminue sa consommation de pesticides notamment
#
# Pourquoi en sortir, il faut continuer à l’améliorer
# Sortir, pour aller vers quoi ? L’importation ? https://twitter.com/LeluOlivier/status/1194242549034209280/photo/1 [LeluOlivier]
# ########
#  Le lobby bio essaie de dire que les pesticides utilisés en bio sont mieux... car ‘naturelles’. Mais ce n’est pas le cas. On utilise beaucoup le cuivre, qui est un poison environmental terrible. « tibogd: @Bnard72494594 @EmmanuelRuimy @VillaniCedric Le lobby bio, il s'en fout probablement. Mais il est en campagne électorale. C'est les consommateurs de bio qu'il vise. — https://twitter.com/tibogd/status/1193865569973526528 » [lizbates217]
# ########
#  Les produits #phytosanitaires font l’objet d’une réglementation européenne très stricte (la plus stricte au monde) qui vise à garantir leur utilisation en préservant les utilisateurs, les consommateurs, les #riverains et l’environnement #EnvoyeSpecial [UIPPorg]
# ########
#  @Menilmuche @GeWoessner @emma_ducros 66000 t/an: moyenne des 10 dernières années pr les substances phyto utilisables en agri conventionnelle et bio. Résidus toxiques? 96,2% des aliments = conformes à la réglementation. Les dépassements ponctuels n’impliquent pas de risque pr la santé des consommateurs #OnRectifie [UIPPorg]
# ########
#  [🌽REPORTAGE #Maïs🌽] Dimanche 20 octobre à 20h50, sur France 5 : "Maïs, pour le meilleur et pour l'épi" : consommateur d'eau, pesticides, herbicides et fongicides ? Entre info et intox, enquête sur cette plante tropicale très utilisée => https://www.programme-tv.net/programme/culture-infos/16212559-mais-pour-le-meilleur-et-pour-lepi/ #agriculture [Marjo_rie_B]
# ########
#  🚜 [#INFOGRAHIE]👩‍🌾
# Qui sont les plus gros consommateurs de #pesticides en #Europe❓ @lepoint fait le point.
# 🇫🇷 La #France se défend bien, et est soucieuse de son #environnement.
#
# #Agribashing #Sauvetonpaysan #agriculture #LePoint #AgricultureDurable https://twitter.com/DesherbageBayer/status/1181792654742323200/photo/1 [DesherbageBayer]
# ########
#  Réflexion de la Pr. Agnès Ricroch (@AgroParisTech) sur les technologies d’édition du génome :  « CRISPR est de fait un allié de l’agroécologie permettant de réduire la consommation de pesticides et d’avoir des plantes adaptées au réchauffement climatique ».
# #POLITICOAgrifood https://twitter.com/EmmanuelRuimy/status/1177569889168613376/photo/1 [EmmanuelRuimy]
# Au fait, on boit pas de glyphosate. https://twitter.com/LeluOlivier/status/1122595732144496640/photo/1 [LeluOlivier]
# ########
#  @ostock1 @Tonio_Logique @Veillerette @coquelicots_ @genefutures @coquelicotsNcy Tout à fait d accord : les BIOs montrez exemple => zéro pesticides memes naturels, zéro antibiotiques dans les élevages, zéro consommations de carburant
# Allez chiche !! [LeluOlivier]
# ########
#  Etude #Iddri "Nourrir l’Europe sans #pesticides, un objectif réaliste"publiée le16 avril :REALISTE VRAIMENT? alors que l'étude pointe "La question de la viabilité économique d’un tel modèle pour les #agriculteurs et les consommateurs qui reste posée"Comme une odeur de #Lyssenko. https://twitter.com/petatJM/status/1119254616561025024/photo/1 [petatJM]
# ########
#  Ne vous inquiétez pas les produit phyto, biocides et anti parasitaires externes veterinaires ou humain : les #pesticides sont évalués. Utilisés selon les précautions d'usage il n'y a pas de #risque. Il faut lire les étiquettes.... « npopravka: @FDUMOULIN60 @fastier_antony Je n'ai jamais compris que les pesticides domestiques soient en vente libre.
# Et je parie que 90% des gens qui pensent que le glyphosate les empoisonne baignent chez eux dans la permethrime et le fipronil du collier du chien 😡 — https://twitter.com/npopravka/status/1118785356575514624 » [fastier_antony]
# ########
#  25 ans d'études sur la #toxicologie des produits #chimiques, #naturels et des #pesticides pour une meilleure protection des consommateurs, applicateurs, riverains. ET bloqué par le petit jeune @genefutures 😉. https://twitter.com/fastier_antony/status/1117031330276106242/photo/1 [fastier_antony]
# ########
#  @lemuetleborgne @fnab_bio @afis @afis_science Je n'ai rien contre les OGM, j'y crois. Mais vous non et la majorité des français aussi, sur la base d'études biaisées genre @GMOSeralini . Donc je #soutienagri avec des produits phyto ou bio tant que la santé des #agriculteurs et des #consommateurs est prise en compte [fastier_antony]
# ########
#  @JLabbeSenat Autre question : quand pensez vous interdire les pesticides et antibiotiques utilisés en BIO. ?
# Parce que remplacer des pesticides de synthèse par d autres produits chimiques genre soufre ou sulfate de cuivre c est pas glorieux et trompe les  consommateurs
# Merci https://twitter.com/LeluOlivier/status/1111369752205774848/photo/1 [LeluOlivier]
# ########
#  @GENINPATRICK2 @MatthiouML @coquelicots_ @fnab_bio Eh bien que les BIOs donnent l exemple en utilisant AUCUN pesticide et abandonné le cuivre, le soufre ...
# Ce sera raccord avec leurs promesses au consommateurs qui sont fausses pour l instant. https://twitter.com/LeluOlivier/status/1110278364462571525/photo/1 [LeluOlivier]
# ########
#  [#Agriculture] Face au rejet par certains consommateurs des pesticides et avec l'arrivée des nvlles technologies, peut-on envisager le "zéro phyto" aujourd'hui ? #StopAuxIdéesRecues [Bayer_FR]
# ########
#  @emma_ducros Oui mais les consommateurs dixit la grande distribution veulent du "zéro pesticide" ou du "sans résidu de pesticide" alors à quand le "zéro datura" il est grand temps de fixer des priorités pour la santé de tous! [BertrandLUCAS49]
# ########
#  [FOCUS sur l'utilisation des #pesticides en France] #agriculture #phytosanitaires #dosages 🧐🇫🇷↘️ « PHautefeuille: #pesticides: La France fait partie des Pays consommant le moins de pesticides à l'hectare (données FAO 2016). La dose pour la France est de 3.7 kg/ha... en 1990 nous étions à 5.9 Kg/ha donc - 37 %!!
#  [#Santé] Les consommateurs, de plus en plus soucieux de leur #alimentation, se posent la question légitime des résidus de #pesticides dans les aliments. Est-ce que présence de résidus veut dire risque ? Faisons le point ici http://bit.ly/2HEj8Tk #StopAuxIdéesReçues #Vidéo [Bayer_FR]
# ########
#  #Pesticides, #mycotoxines et #additifs : « 60 Millions de consommateurs » et l’AFP jouent à nous faire peur #foodbashing #marketingdelaPeur #fakenews http://alerte-environnement.fr/2019/01/25/pesticides-mycotoxines-et-additifs-60-millions-de-consommateurs-et-lafp-jouent-a-nous-faire-peur/ [petatJM]
# ########
#  🚨 Au delà de l’opposition des modèles agricoles (#Glyphosate) et de créer des clivages entre #Science ⚗️ et #Consommateur 😃
#
# ✅ Soyons à l’écoute des problématiques de l’#Agriculture et gardons à l’esprit les notions de : contexte, échelle, etc...
#
# https://www.contrepoints.org/2019/01/20/335099-envoye-special-traitement-malhonnete-glyphosate [Emiliengv_FMC]
# ########
#  La valeur sanitaire du #glyphosate dans l'eau potable est 9000 fois supérieure à la limite réglementaire. Merci à @anses de le faire connaître aux citoyens pour pad qu'ils s'inquiètent « GeWoessner: ... La Vmax (valeur maximale admissible), établie selon des critères de RISQUE TOXICOLOGIQUE. La Vmax du glyphosate dans l’eau destinée à la consommation est fixé à… 900 µg/L. https://twitter.com/GeWoessner/status/1084945557519589379/photo/1 — https://twitter.com/GeWoessner/status/1084945557519589379 » [PaepeIsabelle]
# ########
#  [#Santé] Présence de résidus ne veut pas dire risque ! Pour que les résidus de pesticides représentent un risque pr la santé, il faudrait consommer des aliments dans des quantités supérieures à la normale & ce tous les jours de sa vie #StopAuxIdéesReçues https://www.bayer.fr/agriculture-sante https://twitter.com/Bayer_FR/status/1085924342016471040/video/1 [Bayer_FR]
# ########
#  @PotierDominique @socialistesAN @j_jaures @DSFEurope @MRJC_com @JeunesAgri @FNSEA @ConfPaysanne @Inra_France @partisocialiste @FNEasso @FondationNH @FNAB @LaConvCA M. Potier vous Souhaitez arrêtez aussi les pesticides BIO donc ! (En finir avec les pesticides). Bonne nouvelle
#
# Votre avis sur les » OGM « utilisés en BIO ??  Cf schéma sélection blé RENAN
#
# Les consommateurs ont le droit De savoir. Merci. https://twitter.com/LeluOlivier/status/1085244518021120007/photo/1 [LeluOlivier]
# ########
#  @turelio73
# On en parlait il y a quelques jours...
# Le changement de régime alimentaire n’est pas spécifique du bio ou conventionnel’ et donc non différenciant
#
# Bilan : moins de pesticides (de synthèse) et/ou engrais = + de CO2 !!
# #Climat
# Voir tweet ci-dessous étude En lien « Jacques79556451: 1 agriculture 100% biologique augmenterait les émissions de CO2. Je ne sais pas pourquoi, j'ai dans l'idée que les grds médias vont peu en parler! La bio a évidemment des vertus, mais la question des besoins en surface se pose qd même !
# https://www.bfmtv.com/economie/consommation/une-agriculture-100-biologique-augmenterait-les-emissions-de-co2_AN-201910240083.html via @bfmbusiness — https://twitter.com/Jacques79556451/status/1338167496852054019 » [LeluOlivier]
# ########
#  @synabio Vous avez expliqué que le BIO UTILISE DES PESTICIDES ?
# Dont un métal lourd, cuivre
# BIO = bilan CO2 cata
# Des filières pas toutes claires
# Et des variétés « naturelles »  comme le schéma ci dessous l’illustre
# BIO = obligation de moyen seulement
#
# Qui trompe le consommateur ? https://twitter.com/LeluOlivier/status/1334965506709852163/photo/1 [LeluOlivier]
# ########
#  @LCP @J_Denormandie Et quand certains détruisent les plantes des essais 👉 on en perd du temps 🤨
# Le but : éviter les importations de sucre produit avec des matières actives interdites en 🇫🇷 + limiter la production de CO2 (2 à 3 insecticides en foliaire = carburant consommé...)
# #ceuxquifontlesucre [1Gaillet]
# ########
#  Saviez-vous que la caféine est avant tout un puissant pesticide naturel produit par certaines plantes pour se protéger des parasites ? Cet insecticide entraîne la paralysie ou la mort de insectes qui tenteraient de consommer des feuilles de café ou de thé. https://twitter.com/EmmanuelRuimy/status/1303675985280274432/photo/1 [EmmanuelRuimy]
# ########
#  @Flavien_Gerard @INRAE_France @Anses_fr @INRAE_BFC_Dijon @INRAE_DPT_SPE Les cinquante personnes a l’hôpital il y a un an à la suite de la consommation de crêpes au sarrasin bio et à la datura seront contents de l’apprendre !
#
# Imaginer 50 personnes a l’hôpital à cause du glyphosate, le scandale.
# Là, rien. Pas de relais média. [LeluOlivier]
# ########
#  @bonsens27518404 @AssoPollinis @coquelicots_ En vigne et arboriculture, le BIO consomme + de pesticides qu’en conventionnel en quantité
# C’est aussi les 2 cultures qui sont le + protégées
#
# + de bio = + de pesticides
# Et pas les plus soft (cf comparaison glyphosate /cuivre) https://twitter.com/LeluOlivier/status/1267782998906331136/photo/1 [LeluOlivier]
# ########
#  @Leolecolo @FNSEA @EFSA_EU @France3tv @CharlyBoudet Pourquoi un résidu de produits phytosanitaires devraient être évalués différemment selon qu'il provient d'aliments bio (ex: cuivre) ou d'aliments conventionnels (ex: glyphosate)? Un consommateur qui consomme les deux types d'aliments doit être sécurisé de la même façon [petatJM]
# ########
#  La France, dans la moyenne européenne pour la consommation de produits #phytos #pesticides @France3tv @FNSEA @ChambagriFrance @JeunesAgri @Fragritwittos @FRSEA_Bretagne @JABretagne @ChambagriBzh @JimmyGuerin @Agri_Normandie @JA_Normandie @FrseaNormandie @FRSEAPACA https://twitter.com/UIPPorg/status/1263225802524631040/photo/1 [UIPPorg]
# ########
#  Avant d’être autorisé, un #pesticide doit démontrer à @EFSA_EU qu’il est sans risque pour les consommateurs, les citoyens, les riverains, les promeneurs et l’environnement. @france3Bretagne @ChambagriBzh @FRSEA_Bretagne @FDSEA35 @JAilleetvilaine @JABretagne @ThierryCoue [UIPPorg]
# ########
#  Il bosse pour des cabinets d'avocats US qui cherchent des clients pour faire des procès contre le #glyphosate. Et les consommateurs sont bien mal informés grace à ce genre de personne « will59115: @fastier_antony Conflit d intérêt ? C est à dire il bosse pour un fabricant de pesticide ? Le glyphosate est un pesticide et les consommateurs n’en veulent plus. — https://twitter.com/will59115/status/1261403344389709825 » [fastier_antony]
# ########
#  @gruffat_claude @SKyriakidesEU @EP_Agriculture Good idea ! @yjadot @N_Hulot @rivasi @JDecerle
# And What about organic (BIO) for Apple
# Chemicals x 2 or 3 more !
# Yield / 2 👎
#
# Communiquons au consommateur que le BIO utilise 2 à 3 x+ de pesticides pour un rendement divisé par 2 et un bilan CO2 négatif  ⤵️😰😢 https://twitter.com/LeluOlivier/status/1260510548061491212/photo/1 [LeluOlivier]
# ########
#  [Actu] Résidus cumulés de #pesticides : les premières évaluations concluent à une absence de risque pour le consommateur @EFSA_EU➡️ http://www.uipp.org/Actualites/Residus-cumules-de-pesticides-les-premieres-evaluations-concluent-a-une-absence-de-risque-pour-le-consommateur https://twitter.com/UIPPorg/status/1257216555059994625/photo/1 [UIPPorg]
# ########
#  [Actu] Résidus cumulés de #pesticides : les premières évaluations concluent à une absence de risque pour le consommateur @EFSA_EU ➡️ http://www.uipp.org/Actualites/Residus-cumules-de-pesticides-les-premieres-evaluations-concluent-a-une-absence-de-risque-pour-le-consommateur https://twitter.com/UIPPorg/status/1255858910516436994/photo/1 [UIPPorg]
# ########
#  Résidus de #pesticides 95,5 % des échantillons sont dans les limites légales.Selon @EFSA_EU ces résultats2018 ne sont pas susceptibles de constituer un problème pour la santé des consommateurs. Les mots sont choisis…. 🧐🧐 « EFSA_EU: EFSA’s annual report on #PesticideResidues in food just published. Data gives a snapshot of the presence of residues in #food in the 🇪🇺 and any possible risk to #ConsumerHealth. It also helps risk managers to make decisions on control measures.
# ▶️https://bit.ly/39ErsLs https://twitter.com/EFSA_EU/status/1245645059027947522/photo/1 — https://twitter.com/EFSA_EU/status/1245645059027947522 » https://twitter.com/qualidon/status/1248184067616620544/photo/1 [qualidon]
# ########
#  @Breizh_Girl Bonjour
# Quelques éléments. A vous de juger si pertinent
# Intensifier agriculture = + de récolte = Besoin de moins de surface = + forêt qui pompe CO2.
# A l’inverse pour le BIO.... désolé ..... consomme + de carburant pour remplacer herbicides
#
# Exemple forêt de Haye près de Nancy https://twitter.com/LeluOlivier/status/1245222888577400832/photo/1 [LeluOlivier]
# ########
#  @PacFTV @France3tv @StenkaA @MagnetoTV Pourquoi vous ne dites jamais qu une majeure partie de l augmentation des pesticides est due au soufre et cuivre des agriculteurs Bio ?
# Pourquoi vous ne dites pas que la suppression des neonicotinoides ont entraîné une hausse des  consommation des phytos [DidierBeguery]
# ########
#  Nicolas Chabanne  fondateur @C_qui_le_Patron  un monde sans #pesticides pesticides aujourd'hui non demain il y aura des solutions, c'est le consommateur avec sa carte bleue et son acte d'achat qui envoie une impulsion 🤠 @sieclevert #SIA2020
# https://www.youtube.com/watch?v=WOfUPMqBOIg&list=UUfiittAB66tomkBe63vYnjg&index=16 https://twitter.com/qualidon/status/1232920002774360067/photo/1 [qualidon]
# ########
#  @Konsoleader une application pour détecter des pesticides (* de synthèse)  de @Karethic qui vend du #bio, heu…  comment dire… y aurait pas un "petit" biais quelque part ? sans nommer le mot qui fâche. « konsoleader: @fastier_antony Exactement la seule solution est d’analyser et nous avons trouvé la solution pour que ce soit fait directement par le consommateur régulièrement de façon indépendante et inopinée. — https://twitter.com/konsoleader/status/1231958234551984130 » [fastier_antony]
# Pour les tonnes de pesticides, regarder aussi du côté du BIO, l’augmentation vient en partie du soufre et cuivre, car les vitis BIO consomment + de pesticides https://twitter.com/LeluOlivier/status/1214960083685249031/photo/1 [LeluOlivier]
# ########
#  Mon travail a un rôle primordial pour l’agriculture 🌾
#
# Un produit phytosanitaire, pour être utilisé, doit bénéficier d'une autorisation de mise sur le marché 📝 🔍
#
# Ce qui garantit la sécurité, à la fois pour l'environnement, pour le consommateur, et l'utilisateur ✅ [UIPPorg]
# ########
#  99,99% des pesticides que vous consommez tous les jours sont produits par les plantes elles-mêmes. Votre favori est peut-être d'ailleurs la caféine, un puissant insecticide naturel fabriqué par certaines plantes pour se protéger des parasites.
# https://www.semanticscholar.org/paper/Dietary-pesticides-(99.99-all-natural).-Ames-Profet/c8f0fdb835b07a89b75d5fbca2eaa038566e9ce9 https://twitter.com/EmmanuelRuimy/status/1361295957162393601/photo/1 [EmmanuelRuimy]
# ########
#  Le #biocontrole ne parle pas aux consommateurs  et le #bio surfe sur la fausse image qu'il n'utilise pas de #pesticides  @CarrefourFrance @Bonduelle_Group @credoc @IBMAFrance @PascaleHebel @FruitsLegumesFR 🧐🤠
# https://www.cultivar.fr/sinformer/biocontrole-quen-pensent-carrefour-et-bonduelle https://twitter.com/qualidon/status/1357217120984174594/photo/1 [qualidon]
# ########
#  Le label "zéro résidus de #pesticides s'intalle dans les étals @pleinchamp @iciLaTerre_Agri @FiliereCRC
# https://www.pleinchamp.com/actualite/le-label-zero-residu-de-pesticides-s-installe-dans-les-etals-et-dans-l-esprit-des-consommateurs #pleinchamp https://twitter.com/qualidon/status/1352627202555326470/photo/1 [qualidon]
# ########
#  @Legoaldesyeti Si y a 1 intérêt pour le Bio :
# La marge de distribution !!
#
# Pour le reste, c’est du co2 en +, de la déforestation, qq intoxication datura,
# Hausse quantités de pesticides
#
# Si des agris /consommateurs en veulent, pas de souci, mais n’appelez pas ça « écologique » ou « santé » [LeluOlivier]
# ########
#  @laurentbike @benj_thi @VergersEcoResp @Mediafel @MacLesggy @BruCardot @agritof60 @GrainHedger @JulienDive @J_Denormandie @j_saintraymond @BotTrubuil @GabrielleDufou5 @SandrineGabo Ben en fait, ils utilisent des pesticides moins efficaces, donc il faut en mettre + et au final on récolte moins à surface égale
# Voilà
# D’où les prix supérieurs des produits BIO pour le consommateur
#
# Voir étude INRA ci-dessous https://twitter.com/LeluOlivier/status/1406672439703187461/photo/1 [LeluOlivier]
# ########
#  ▶Résidus de #pesticides dans les aliments, un taux de conformité à 96 %
# Pour en savoir plus ⤵ « UIPPorg: Selon le dernier rapport de l’@EFSA_EU, les produits alimentaires analysés en 2019 ne sont pas susceptibles de constituer un problème pour la santé des consommateurs. ✅
#
# Retrouvez les enseignements du rapport ici ⬇️ — https://twitter.com/UIPPorg/status/1385493443489812480 » [DESANGOSSE]
# ########
#  Résidus de #pesticides dans l’alimentation, l’Efsa annonce un taux de conformité de 96,1 % et conclut à une absence de risque pour le consommateur. Les dépassements des limites maximales de résidus sont plus élevés chez les produits importés.
# https://campagnesetenvironnement.fr/residus-de-pesticides-dans-lalimentation-lefsa-annonce-un-taux-de-conformite-de-961/ [DESANGOSSE]

# %%
for x in tweets.text.loc[(tweets.logic=="Procés de Monsanto") & (tweets.text.str.lower().str.contains("triskalia"))]:
    print('########\n', x)

# %%
import numpy as np
import re
import scipy
import statsmodels as sm
import statsmodels.stats
import statsmodels.stats.proportion

import statsmodels.api as sm
statsmodels.__version__
# Out:
# '0.14.6'

# %%
list_nb_cluster = []
dict_nb_cluster = {}

log_or = []
log_upper = []
log_lower = []
world = []
list_theme = []

for x in list_column:
    nb_indus = np.sum(d1_industry[x])
    nb_indus_other_clust = np.sum(d1_industry["somme"]) - nb_indus
    nb_total = np.sum(d1[x])
    nb_other = nb_total - nb_indus
    nb_total_other = np.sum(d1["somme"]) - np.sum(d1_industry["somme"])
    nb_other_clust = nb_total_other - nb_other
    list_nb_cluster.append(nb_indus)
    #dict_nb_cluster[x] = {"indus": int(nb_indus), "non-indus":int(nb_other), "total":int(nb_total)}
    arr = np.array([[nb_indus, nb_indus_other_clust], 
                        [nb_other, nb_other_clust]])
    #print(arr)
        
    if 1:
                   table=statsmodels.stats.contingency_tables.Table2x2(arr)


                   logodd=table.log_oddsratio
                   [logodd_minus,logodd_plus]=table.log_oddsratio_confint(.95)
                   #print (logodd_minus,logodd_plus)
                   deviation=logodd
                   deviation_upper=logodd_plus
                   deviation_lower=logodd_minus
    log_or.append(deviation)
    log_upper.append(logodd_plus)
    log_lower.append(logodd_minus)
    list_theme.append(x)
    

    
#dict_nb_cluster

# %%
data = {"theme":list_theme,"nb":list_nb_cluster,"log_or":log_or,"log_upper": log_upper, "log_lower":log_lower}
logor = pd.DataFrame(data).sort_values(["log_or"], ascending= True)
logor
# Out:
#                                       theme    nb    log_or  log_upper  \
# 9                               Chlordécone     0 -4.656988  -4.568292
# 12                       Procès de Monsanto    84 -0.846841  -0.839881
# 11                          Néonicotinoïdes   118 -0.800937  -0.795032
# 3                    Épandages et riverains    29 -0.687593  -0.675840
# 10                La mortalité des abeilles   136 -0.676833  -0.671314
# 14          Politiques agricoles françaises    39 -0.675876  -0.665725
# 6                         Affaire Triskalia     2 -0.597953  -0.553363
# 15              La crise de la biodiversité    58 -0.382746  -0.374384
# 16               Perturbateurs endocriniens    25 -0.348127  -0.335452
# 1                             Plan écophyto     6 -0.320510  -0.294706
# 19                 Réchauffement climatique    18 -0.275804  -0.260875
# 17                       Pollution de l'eau     5 -0.231197  -0.202916
# 21                        Troubles de santé   114 -0.223168  -0.217145
# 22                               Glyphosate  1339 -0.029562  -0.027327
# 20                    Régulation européenne   173  0.019345   0.024289
# 7                     Les espèces nuisibles    84  0.179850   0.186859
# 2   Transition écologique et débats publics    11  0.320703   0.339893
# 18                    Sécurité des aliments   139  0.449393   0.454906
# 0                                    Le vin   129  0.483632   0.489348
# 13                   La science en question   453  0.491362   0.494576
# 4                        Le rapport du CIRC    66  0.538505   0.546428
# 8                             Le virus Zika     4  0.565135   0.597039
# 5                                      SDHI   311  2.115476   2.119456
#
#     log_lower
# 9   -4.745684
# 12  -0.853801
# 11  -0.806842
# 3   -0.699346
# 10  -0.682352
# 14  -0.686027
# 6   -0.642543
# 15  -0.391108
# 16  -0.360802
# 1   -0.346313
# 19  -0.290734
# 17  -0.259477
# 21  -0.229191
# 22  -0.031796
# 20   0.014401
# 7    0.172841
# 2    0.301514
# 18   0.443881
# 0    0.477915
# 13   0.488149
# 4    0.530583
# 8    0.533231
# 5    2.111497

# %%
import seaborn as sns

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots(1, figsize=(15,6), sharey = True, sharex=False)
#ax.set_xscale("log")

for n, i in enumerate(logor.theme):
        y = [i, i]
        x = [logor["log_lower"].iloc[n], logor["log_upper"].iloc[n]]

        ax.plot(x, y, "_-", markersize = 20, #color=couleur, 
                    markeredgewidth= 3, linewidth = 3)

        y = i
        x = logor["log_or"].iloc[n]
        ax.plot(x, y, "o", #color=couleur,
                markersize = 10)
        ax.yaxis.set_tick_params(labelcolor="black", labelsize=12)
        #ax.set_title(j, fontsize=14, fontweight='bold')
        ax.axvline(0, ls='--', linewidth=1, color='red')
        ax.set_xlabel("log odds ratio", fontsize=16)
        ax.set_ylabel("", fontsize=16)

# %%
freq_all

# %%
f = freq_all_cleaned.loc[freq_all_cleaned.logic=="industry_pesticide"]#.replace(-10.0, -np.inf)#.sort_values('zscore', ascending=False)
nb_cluster = dict(zip(freq_all_cleaned.cluster, freq_all_cleaned.nb))
logor["zscore"] = logor.theme.map(nb_cluster.get)

# %%
sns.set_style("whitegrid")
f.loc[f.zscore < 0, "sur-représenté"] = "sous-représenté"
f.loc[f.zscore > 0, "sur-représenté"] = "sur-représenté"
fig = sns.barplot(f.sort_values("nb", ascending = False), x = "nb", y = "cluster", hue = "sur-représenté")

# %%
d2 = d.loc[(d.somme>0) & ~(d.logic.isna())]
d2_industry = d2.loc[d2.industry==True]
list_nb_cluster = []
dict_nb_cluster = {}

log_or = []
log_upper = []
log_lower = []
world = []
list_theme = []

for x in list_column:
    nb_indus = np.sum(d2_industry[x])
    nb_indus_other_clust = np.sum(d2_industry["somme"]) - nb_indus
    nb_total = np.sum(d2[x])
    nb_other = nb_total - nb_indus
    nb_total_other = np.sum(d2["somme"]) - np.sum(d2_industry["somme"])
    nb_other_clust = nb_total_other - nb_other
    list_nb_cluster.append(nb_indus)
    #dict_nb_cluster[x] = {"indus": int(nb_indus), "non-indus":int(nb_other), "total":int(nb_total)}
    arr = np.array([[nb_indus, nb_indus_other_clust], 
                        [nb_other, nb_other_clust]])
    #print(arr)
        
    if 1:
                   table=statsmodels.stats.contingency_tables.Table2x2(arr)


                   logodd=table.log_oddsratio
                   [logodd_minus,logodd_plus]=table.log_oddsratio_confint(.95)
                   #print (logodd_minus,logodd_plus)
                   deviation=logodd
                   deviation_upper=logodd_plus
                   deviation_lower=logodd_minus
    log_or.append(deviation)
    log_upper.append(logodd_plus)
    log_lower.append(logodd_minus)
    list_theme.append(x)
    

    
#dict_nb_cluster

# %%
data = {"theme":list_theme,"nb":list_nb_cluster,"log_or":log_or,"log_upper": log_upper, "log_lower":log_lower}
logor = pd.DataFrame(data).sort_values(["log_or"], ascending= True)

sns.set_style("whitegrid")
fig, ax = plt.subplots(1, figsize=(15,6), sharey = True, sharex=False)
#ax.set_xscale("log")

for n, i in enumerate(logor.theme):
        y = [i, i]
        x = [logor["log_lower"].iloc[n], logor["log_upper"].iloc[n]]

        ax.plot(x, y, "_-", markersize = 20, #color=couleur, 
                    markeredgewidth= 3, linewidth = 3)

        y = i
        x = logor["log_or"].iloc[n]
        ax.plot(x, y, "o", #color=couleur,
                markersize = 10)
        ax.yaxis.set_tick_params(labelcolor="black", labelsize=12)
        #ax.set_title(j, fontsize=14, fontweight='bold')
        ax.axvline(0, ls='--', linewidth=1, color='red')
        ax.set_xlabel("log odds ratio", fontsize=16)
        ax.set_ylabel("", fontsize=16)

# %%
d.logic.unique()

# %%
#d2 = d.loc[(d.somme>0) & ~(d.logic.isna())]
d2_agroind = d2.loc[d2.logic=='Pesticide_free_agriculture']
list_nb_cluster = []
dict_nb_cluster = {}

log_or = []
log_upper = []
log_lower = []
world = []
list_theme = []

for x in list_column:
    nb_indus = np.sum(d2_agroind[x])
    nb_indus_other_clust = np.sum(d2_agroind["somme"]) - nb_indus
    nb_total = np.sum(d2[x])
    nb_other = nb_total - nb_indus
    nb_total_other = np.sum(d2["somme"]) - np.sum(d2_agroind["somme"])
    nb_other_clust = nb_total_other - nb_other
    list_nb_cluster.append(nb_indus)
    #dict_nb_cluster[x] = {"indus": int(nb_indus), "non-indus":int(nb_other), "total":int(nb_total)}
    arr = np.array([[nb_indus, nb_indus_other_clust], 
                        [nb_other, nb_other_clust]])
    #print(arr)
        
    if 1:
                   table=statsmodels.stats.contingency_tables.Table2x2(arr)


                   logodd=table.log_oddsratio
                   [logodd_minus,logodd_plus]=table.log_oddsratio_confint(.95)
                   #print (logodd_minus,logodd_plus)
                   deviation=logodd
                   deviation_upper=logodd_plus
                   deviation_lower=logodd_minus
    log_or.append(deviation)
    log_upper.append(logodd_plus)
    log_lower.append(logodd_minus)
    list_theme.append(x)

# %%
data = {"theme":list_theme,"nb":list_nb_cluster,"log_or":log_or,"log_upper": log_upper, "log_lower":log_lower}
logor = pd.DataFrame(data).sort_values(["log_or"], ascending= True)

sns.set_style("whitegrid")
fig, ax = plt.subplots(1, figsize=(15,6), sharey = True, sharex=False)
#ax.set_xscale("log")

for n, i in enumerate(logor.theme):
        y = [i, i]
        x = [logor["log_lower"].iloc[n], logor["log_upper"].iloc[n]]

        ax.plot(x, y, "_-", markersize = 20, #color=couleur, 
                    markeredgewidth= 3, linewidth = 3)

        y = i
        x = logor["log_or"].iloc[n]
        ax.plot(x, y, "o", #color=couleur,
                markersize = 10)
        ax.yaxis.set_tick_params(labelcolor="black", labelsize=12)
        #ax.set_title(j, fontsize=14, fontweight='bold')
        ax.axvline(0, ls='--', linewidth=1, color='red')
        ax.set_xlabel("log odds ratio", fontsize=16)
        ax.set_ylabel("", fontsize=16)
